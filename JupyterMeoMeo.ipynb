# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Long M. Nguyen__
# Undergraduate Student at Alma Mater Studiorum - Università di Bologna

# %% [markdown]
# *I am interested in Data Science because I am curious about data, and I want to gain insight from data to solve real-world problems*

# %% [markdown]
# ### My code will prompt the user for his/her name, and then display "he/she is a wonderful person"

# %%
#prompt the user for input

name = input("Please enter your name: \n")

#display "he/she is a wonderful person"

print(f"You are the cutest person in my life, {name}")
# Out:
# Please enter your name:
# Ha Trang
# You are the cutest person in my life, Ha Trang

# %% [markdown]
# #Hyperlinks  <a href="https://www.coursera.org/professional-certificates/ibm-data-science">IBM Data Science Professional Certificate on Coursera</a>
# #Images ![image.png](attachment:image.png)
# #Blocked quotes
# >This is a blocked quote
